# %% [raw]
# ### Arithmetic Operators
#
# ##Arithmetic operators are used with objects (mainly numeric ones) to perform math operations:
#
# | Operator 	| Name           	| Example 	|
# |----------	|----------------	|---------	|
# | +        	| Addition       	| x + y   	|
# | -        	| Subtraction    	| x - y   	|
# | *        	| Multiplication 	| x * y   	|
# | /        	| Division       	| x / y   	|
# | %        	| Modulus        	| x % y   	|
# | **       	| Exponentiation 	| x ** y  	|
# | //       	| Floor division 	| x // y  	|

# %%
seven=7
seven.__sub__(4)
# print(7-4)
# Out:
# 3

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
min_salary=50_000  # _ is ignored
max_salary=100_000
avg_salary=(min_salary+max_salary)/2
print(avg_salary)
# Out:
# 75000.0

# %% [markdown]
# ### Assignment Operators
#
# Assignment operators are used to assign values to variables.
#
# | Operator | Name                | Example |
# |----------|---------------------|---------|
# | =        | Assign              | x = y   |
# | +=       | Add and assign      | x += y  |
# | -=       | Subtract and assign | x -= y  |
# | *=       | Multiply and assign | x *= y  |
# | /=       | Divide and assign   | x /= y  |
# | %=       | Modulus and assign  | x %= y  |
# | **=      | Exponent and assign | x **= y |
# | //=      | Floor divide and assign | x //= y  |

# %%
Love1='Viyan'
Love2='Valan'
Love1,Love2=Love2,Love1
Love1,Love2
# Out:
# ('Valan', 'Viyan')

# %%
x=1
x=1+x
x
# Out:
# 2

# %%
x=1
x+=1
x
# Out:
# 2

# %%
a=5
a-=2
b=5
b*=2
c=5
c/=2
d=5
d%=2
e=5
e**=2
f=5
f//=2
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# 3
# 10
# 2.5
# 1
# 25
# 2

# %% [markdown]
# ### Comparison Operators
#
# Comparison operators compare two values and determine the relation between them.
#
# | Operator | Name                  | Example |
# |----------|-----------------------|---------|
# | ==       | Equal to              | x == y  |
# | !=       | Not equal to          | x != y  |
# | >        | Greater than          | x > y   |
# | <        | Less than             | x < y   |
# | >=       | Greater than or equal | x >= y  |
# | <=       | Less than or equal    | x <= y  |

# %%
a==b
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(b<=a)
# Out:
# False
# True
# False
# True
# False
# False

# %% [markdown]
# <span style= "color:green;font-weight:bold;font-size:32px;"> Practise prompts </span>

# %%
# Calculate the total annual salary for a data scientist given the monthly salary.
# The variable monthly_salary is set to 8000.
monthly_salary=80_00
annual_salary=monthly_salary*12
print(annual_salary)
# Out:
# 96000

# %%
# Determine if the average salary of a data analyst is greater than that of a data scientist.
# The variables avg_salary_analyst and avg_salary_scientist are set to 70000 and 85000 respectively.
avg_salary_analyst = 70000
avg_salary_scientist = 85000
print(avg_salary_analyst>avg_salary_scientist)
# Out:
# False

# %%
# Calculate the remainder when the total number of job applications (variable total_applications is set to 123) is 
# divided by the number of job openings (variable job_openings is set to 67).

total_applications =123
job_openings = 67

job_openings_needed=total_applications%job_openings
print(job_openings_needed)
# Out:
# 56

# %%
#Increment (or increase) the variable job_postings by 5. The variable job_postings is intially set to 20.

job_postings = 20
job_postings += 5
print(job_postings)
# Out:
# 25

# %%
#Calculate the average salary from the minimum and maximum salaries. 
#The variables min_salary and max_salary are set to 50000 and 120000 respectively.

min_salary = 50000
max_salary = 120000
avg_salary=(min_salary+max_salary)/2
print(avg_salary)
# Out:
# 85000.0

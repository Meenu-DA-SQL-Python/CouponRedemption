# %%
! pip list

# %%
import random
random.randint(50000,100000)
# Out:
# 80960

# %%
import statistics
# Out:
# 77477.4

# %%
salary=[random.randint(50000,100000) for _ in range(10000)]

# %%
# %%timeit
statistics.mean(salary)
# Out:
# 6.71 ms ± 440 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary)
# Out:
# 625 µs ± 9.94 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
my_array=np.array([1,2,3,4])
mean_array=my_array.mean()
print(mean_array)
# Out:
# 2.5

# %%
job_titles=np.array(['Data Analyst','Data Scientist','Data Engineer','Machine Leanring Engineer','AI engineer','AI Engineer'])
base_salaries=np.array([60000,80000,125000,90000,np.nan])
bonus_rates=np.array([.05,.1 , .08 , 0.12, np.nan])

# %%
total_salaries=base_salaries* (1+ bonus_rates)
print(total_salaries)
# Out:
# [ 63000.  88000. 135000. 100800.]

# %%
total_salaries= base_salaries * (1+ bonus_rates)
print(total_salaries)
# Out:
# [ 63000.  88000. 135000. 100800.     nan]

# %%
print(np.nanmean(total_salaries))
# Out:
# 96700.0

# %% [markdown]
# <span style =" color:green; font-weight:bold;font-size:32px;"> Practise Prompts </span>

# %%
# Problem Statement:
# Create a NumPy array representing the number of job applications received each day for a week (7 days). 
# The array should be called applications and contain the following numbers: [10, 15, 7, 20, 25, 30, 5]. 
# Print the array.


applications_list = [10, 15, 7, 20, 25, 30, 5]

applications=np.array(applications_list)

print(applications)
# Out:
# [10 15  7 20 25 30  5]

# %%
# Problem Statement:
# Create a NumPy array representing the number of job postings for different job titles called postings.
# The array contains [10, 15, 7, 20, 25, 30, 5]. Use slicing to get the number of postings for the first three job titles.

postings_list = [10, 15, 7, 20, 25, 30, 5]
np_posting_list=np.array(postings_list)

job=np_posting_list[0:3]
print(job)
# Out:
# [10 15  7]

# %%
# Problem Statement:
# Create a NumPy array representing the salaries called salaries offered for five different job positions. 
# Calculate the highest and lowest salary using NumPy functions. 

salaries_list = [70000, 85000, 60000, 95000, 80000]

sal_audit=np.array(salaries_list)

high_sal=max(sal_audit)

print(high_sal)

low_sal=min(sal_audit)

print(low_sal)
# Out:
# 95000
# 60000

# %%
num2=lambda x :x+1

num2(3)
# Out:
# 4

# %%
(lambda x,y:x*2+y)(3,4)
# Out:
# 10

# %%
salary=[100,90,70,80,50]

def cal_sal(base_sal,bonus=0.1):
     return base_sal * (1+bonus)
   
new_salary= [cal_sal(salary) for salary in salary]
 
print(new_salary)
# Out:
# [110.00000000000001, 99.00000000000001, 77.0, 88.0, 55.00000000000001]

# %%
total_salary=[sarlary for sarlary in salary]
total_salary
# Out:
# [100, 90, 70, 80, 50]

# %%
total_salary=[sarlary for sarlary in salary]
total_salary
# Out:
# [100, 90, 70, 80, 50]

# %%
new_salary= [(lambda x: x*(1+0.1))(salary) for salary in salary]
new_salary
# Out:
# [110.00000000000001, 99.00000000000001, 77.0, 88.0, 55.00000000000001]

# %%
new_salary= [salary *1.01 for salary in salary]
new_salary
# Out:
# [101.0, 90.9, 70.7, 80.8, 50.5]

# %%
jobs_data = [
    {'job_title': 'Data Scientist',  'job_skills': ['Python', 'Machine Learning'], 'remote': True},
    {'job_title': 'Data Analyst',  'job_skills': ['Excel', 'SQL'], 'remote': False},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Keras'], 'remote': True},
    {'job_title': 'Software Developer', 'job_skills': ['Java', 'C++'], 'remote': True},
    {'job_title': 'Data Scientist', 'job_skills': ['R', 'Statistics'], 'remote': False}
]

# %%
help(filter)
# Out:
# Help on class filter in module builtins:
#
# class filter(object)
#  |  filter(function or None, iterable) --> filter object
#  |
#  |  Return an iterator yielding those items of iterable for which function(item)
#  |  is true. If function is None, return the items that are true.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
list(filter(lambda job:job['remote'] and "Python" in  job['job_skills'],jobs_data))
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'Machine Learning'],
#   'remote': True},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Keras'],
#   'remote': True}]

# %% [markdown]
# <span style ="color:green; font-width:bold; font-size:32px;"> Practise Prompts </span>

# %%
# Problem Statement:
# Create a lambda function to calculate the average salary from a list of salaries. 
# With salaries set as [95000, 120000, 105000, 90000, 130000].


salaries = [95000, 120000, 105000, 90000, 130000]

avg =lambda sal : sum(sal)/len(sal)

avg_salary=avg(salaries)

avg_salary
# Out:
# 108000.0

# %%
# Create a lambda function to check if a job title contains the word 'Data' and use it to filter a list of job titles. 
# With job_titles set to ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst'].

job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']


dataworld= lambda x : 'Data' in  x 
filteredlist=list(filter(dataworld,job_titles))
filteredlist
# Out:
# ['Data Scientist', 'Data Engineer', 'Data Analyst']

# %%
# Create a lambda function to filter remote job postings that require Python skills from a list of job postings.
# The list for the variable job_postings is shown below.

job_postings = [
    {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
    {'title': 'Data Analyst', 'skills': ['Excel', 'SQL'], 'remote': False},
    {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True},
    {'title': 'Software Developer', 'skills': ['Java', 'C++'], 'remote': True}
]



for job in job_postings:
    for skill in job['skills']:
        print(skill)

        
filter_postings = lambda posting: 'Python' in posting['skills'] and posting['remote']
remote_python_postings = list(filter(filter_postings, job_postings))
remote_python_postings
# Out:
# Python
# SQL
# Excel
# SQL
# Python
# TensorFlow
# Java
# C++
# [{'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
#  {'title': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow'],
#   'remote': True}]

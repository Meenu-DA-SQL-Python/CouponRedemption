# %%
open(r"/Users/Meenu/Desktop/Meenu Doc/Databases/CRedemption/campaign_data.csv")
# Out:
# <_io.TextIOWrapper name='/Users/Meenu/Desktop/Meenu Doc/Databases/CRedemption/campaign_data.csv' mode='r' encoding='UTF-8'>

# %%
file=open(ç

# %%
file.read()
# Out:
# 'campaign_id,campaign_type,start_date,end_date,campaigning_days\n24,Y,21-10-2013,20-12-2013,60\n25,Y,21-10-2013,22-11-2013,32\n20,Y,07-09-2013,16-11-2013,70\n23,Y,08-10-2013,15-11-2013,38\n21,Y,16-09-2013,18-10-2013,32\n22,X,16-09-2013,18-10-2013,32\n18,X,10-08-2013,04-10-2013,55\n19,Y,26-08-2013,27-09-2013,32\n17,Y,29-07-2013,30-08-2013,32\n16,Y,15-07-2013,16-08-2013,32\n13,X,19-05-2013,05-07-2013,47\n11,Y,22-04-2013,07-06-2013,46\n12,Y,22-04-2013,24-05-2013,32\n10,Y,08-04-2013,10-05-2013,32\n9,Y,11-03-2013,12-04-2013,32\n8,X,16-02-2013,05-04-2013,48\n7,Y,02-02-2013,08-03-2013,34\n6,Y,28-01-2013,01-03-2013,32\n3,Y,22-12-2012,16-02-2013,56\n5,Y,12-01-2013,15-02-2013,34\n4,Y,07-01-2013,08-02-2013,32\n1,Y,12-12-2012,18-01-2013,37\n2,Y,17-12-2012,18-01-2013,32\n30,X,19-11-2012,04-01-2013,46\n29,Y,08-10-2012,30-11-2012,53\n28,Y,16-09-2012,16-11-2012,61\n27,Y,25-08-2012,27-10-2012,63\n26,X,12-08-2012,21-09-2012,40\n'

# %%
content=file.read()
file.close()

# %%
import pandas as pd
contents=pd.read_csv(r"/Users/Meenu/Desktop/Meenu Doc/Databases/CRedemption/campaign_data.csv")
print(contents['campaigning_days'].sum())
# Out:
# 1172

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# altgraph                          0.17.2
# anyio                             4.8.0
# appnope                           0.1.4
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# asttokens                         3.0.0
# async-lru                         2.0.4
# attrs                             25.1.0
# babel                             2.17.0
# beautifulsoup4                    4.13.3
# bleach                            6.2.0
# certifi                           2025.1.31
# cffi                              1.17.1
# charset-normalizer                3.4.1
# comm                              0.2.2
# debugpy                           1.8.13
# decorator                         5.2.1
# defusedxml                        0.7.1
# exceptiongroup                    1.2.2
# executing                         2.2.0
# ...

# %%
# Problem Statement:
# Use the os library to list all files in the current directory and print their names with the function os.listdir('.').

# Hint:
# Use the os.listdir function to get the list of files in the current directory, which is denoted by: '.'

# %%
import os
files = os.listdir('.')
for file in files:
    print(file)
# Out:
# my_module.py
# 08_Lists.ipynb
# 20_Library..ipynb
# 09_Dictionaries.ipynb
# job_analyser.py
# 06_Operators_Part_1.ipynb
# 07_Conditional_Statements.ipynb
# 04_Strings.ipynb
# 18_Modules.ipynb
# 12_Operators_Part_2.ipynb
# 1_Getting_Started.ipynb
# 19_Exercise_Python_Library.ipynb
# 15_Exercise_Basics.ipynb
# 17_Lambda.ipynb
# .ipynb_checkpoints
# 02.1_Python_Terms.ipynb.ipynb
# 16_Functions.ipynb
# 03_Data_Types.ipynb
# 13_Loops.ipynb
# 05_String_Formatting.ipynb
# 10_Sets.ipynb
# 14_List_Comprehensions.ipynb
# 11_Tuples_range.ipynb

# %%
# Library
# Problem Statement:
# Use the requests library to fetch data from the URL 'https://pokeapi.co/api/v2/pokemon/pikachu' and print the JSON response.

# Code Needed:
# url = 'https://pokeapi.co/api/v2/pokemon/pikachu'
import requests
url = 'https://pokeapi.co/api/v2/pokemon/pikachu'

response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'abilities': [{'ability': {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'lightning-rod', 'url': 'https://pokeapi.co/api/v2/ability/31/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 112, 'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/25.ogg', 'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/25.ogg'}, 'forms': [{'name': 'pikachu', 'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}], 'game_indices': [{'game_index': 84, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 84, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 84, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 25, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 25, 'version': {'name': 'sil
# ...

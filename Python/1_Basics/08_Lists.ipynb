# %% [markdown]
# Here's a quick comparison between these 4 container data types:
#
# | Feature          | List                                  | Dictionary                           | Set                                | Tuple                             |
# |------------------|---------------------------------------|--------------------------------------|------------------------------------|-----------------------------------|
# | Syntax           | `[item1, item2, ...]`                 | `{'key1': value1, 'key2': value2}`   | `{item1, item2, ...}`              | `(item1, item2, ...)` or `item,`  |
# | Type of Data     | Sequence                              | Mapping                              | Set                                | Sequence                          |
# | Order            | Ordered                               | Unordered                            | Unordered                          | Ordered                           |
# | Indexing         | Yes (by index)                        | Yes (by key)                         | No                                 | Yes (by index)                    |
# | Duplicate Values | Allowed                               | Values can be duplicated, keys cannot| Not allowed                        | Allowed                           |
# | Mutability       | Mutable                               | Mutable                              | Mutable                            | Immutable                         |
# | Usage            | For a collection of ordered items     | For key-value pairs                  | For unique items                   | For fixed data                    |

# %% [markdown]
# 1. job_skills.append()-- add item only at the last
# 2. job_skills.insert(index, value)-- add item in a particular idex space
# 3. job_skills.remove()
# 4. job_skills.index()
# 5. _skills.pop()
# ## Direct indexing vs slicing
#  Direct index returns string and slicing returns list
#
# ## Accessing multiple objects inside the list using slice
#
# 1. list(start:end:step)
# 2. step default to 1
# ## unpacking
# 1. (variable1,*variable2)= list_name
# 2. the "*" unpacks the remaining value of the list
#
# ## Mutable
# The id of the objects does't change after modifying the object items
# Example : The id of the list doesn't affect before or after adding or remvoing an item from the list

# %%
my_list=[1 ,'SQL',[2,'Python']]
my_list
# Out:
# [1, 'SQL', [2, 'Python']]

# %%
job_skills=['sql','Cognos','R','Python']
job_skills.append('Tableau')
job_skills
# Out:
# ['sql', 'Cognos', 'R', 'Python', 'Tableau']

# %%
job_skills.remove('R')
job_skills
# Out:
# ['sql', 'Cognos', 'Python', 'Tableau']

# %%
len(job_skills)
# Out:
# 4

# %%
job_skills.index('Python')
# Out:
# 2

# %%
job_skills[2]
# Out:
# 'Python'

# %%
job_skills.insert(3,'Excel')
job_skills
# Out:
# ['sql', 'Cognos', 'Python', 'Excel', 'Tableau']

# %%
job_skills
# Out:
# ['sql', 'Cognos', 'Python', 'Excel', 'Tableau']

# %%
job_skills

# %%
#Slicing
meenu_food=['Briyani','Pasta','Noodles','Idly']
viyan_food=['Sandwish','Laksa','Parota','Salad','noodles']
all_food=meenu_food+viyan_food
print(all_food)
# Out:
# ['Briyani', 'Pasta', 'Noodles', 'Idly', 'Sandwish', 'Laksa', 'Parota', 'Salad', 'noodles']

# %%
all_food[2:3]
# Out:
# ['Noodles']

# %%
all_food[2:4]
# Out:
# ['Noodles', 'Idly']

# %%
all_food[2:]
# Out:
# ['Noodles', 'Idly', 'Sandwish', 'Laksa', 'Parota', 'Salad', 'noodles']

# %%
all_food[:3]
# Out:
# ['Briyani', 'Pasta', 'Noodles']

# %%
all_food[::2]
# Out:
# ['Briyani', 'Noodles', 'Sandwish', 'Parota', 'noodles']

# %%
all_food[::3]
# Out:
# ['Briyani', 'Idly', 'Parota']

# %%
all_food[-1:]
# Out:
# ['noodles']

# %%
all_food[-2:]
# Out:
# ['Salad', 'noodles']

# %%
len(all_food)
# Out:
# 9

# %% [markdown]
# food1,food2,food3,food4,food5,food6,food7,food8,food9=all_food
# print(food3)

# %%
good_food,*ok_food=all_food
good_food
# Out:
# 'Briyani'

# %%
print(ok_food)
# Out:
# ['Pasta', 'Noodles', 'Idly', 'Sandwish', 'Laksa', 'Parota', 'Salad', 'noodles']

# %%
#mutable
meenu_food
print(id(meenu_food))
# Out:
# 4401099968

# %%
meenu_food.append('aarvee')
print(meenu_food)
print(id(meenu_food))
# Out:
# ['Briyani', 'Pasta', 'Noodles', 'Idly', 'aarvee', 'aarvee', 'aarvee']
# 4401099968

# %% [markdown]
# <span style= "color:green;font-width:bold;font-size:32px;"> Practise Prompts </span>

# %%
# Access the second job title in the list of job titles for data science roles and print it. The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].

job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
print(job_titles[1:2])
print(job_titles[1])
# Out:
# ['Data Analyst']
# Data Analyst

# %%
# Problem Statement:
# Change the third job title in the list of job titles for data science roles to 'AI Specialist' and print the updated list. The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].

job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
job_titles[2]='AI Specialist'
job_titles
# Out:
# ['Data Scientist', 'Data Analyst', 'AI Specialist']

# %%
#Problem Statement:
#Slice the list of job titles for data science roles to get the first two job titles and print the result. 
#The list is ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer'].

job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer']
data_science=job_titles[0:2]
print(data_science)
# Out:
# ['Data Scientist', 'Data Analyst']

# %%
# Problem Statement:
# Add a new job title 'Data Engineer' to the end of the list of job titles for data science roles and print the updated list.
# The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].

job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
job_titles.append('Data Engineer')
print(job_titles)
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer']

# %%
# Problem Statement:
# Insert a new job title 'Business Analyst' at the second position in the list of job titles for data science roles and print the updated list. The variable job_titles is set to ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer'].

job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
job_titles.insert(1,'Business Analyst')
print(job_titles)
# Out:
# ['Data Scientist', 'Business Analyst', 'Data Analyst', 'Machine Learning Engineer']

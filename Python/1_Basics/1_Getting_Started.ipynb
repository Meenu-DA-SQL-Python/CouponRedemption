# %%
2+2
# Out:
# 4

# %%
3*3
# Out:
# 9

# %%
2+2
3+6
# Out:
# 9

# %%
print(2+2)
print(3+3)
# Out:
# 4
# 6

# %%
print(2+3)
# Out:
# 5

# %%
# !ls
# Out:
# 02.1_Python_Terms.ipynb.ipynb 1_Getting_Started.ipynb

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 430 µs ± 18.4 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
L=[]
for n in range(10):
    L.append(n**2)
# Out:
# 4.76 µs ± 555 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:26px;"> Practise prompts </span>

# %%
company_name='Data Works'
job_title='Data Engineer'
wfh=True

# %%
print(company_name,job_title,wfh)
# Out:
# Data Works Data Engineer True

# %%
base_salary=120000
bonus=20000
total_compensation = base_salary+bonus

# %%
total_compensation
# Out:
# 140000

# %%
annual_salary=72000
monthly_salary=annual_salary/12
monthly_salary
# Out:
# 6000.0

# %%
print(monthly_salary)
# Out:
# 6000.0

# %%
job_title= 'Data Scientist' 
company_name ='AI Solutions'
salary=110000
bonus=0.1
total_compensation=salary+(salary*bonus)

print(f" Job: {job_title}\n Company name:  {company_name}\n Salary: {total_compensation}")
# Out:
#  Job: Data Scientist
#  Company name:  AI Solutions
#  Salary: 121000.0

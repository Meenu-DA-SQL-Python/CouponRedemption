# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.name='job_index'

# %%
df.head(10)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 7                 Data Engineer
# 8              Business Analyst
# 9                Data Scientist
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 7                                              Data Engineer
# ...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_usa=df[df['job_country']=='United States']
df_usa.reset_index(inplace=True)
df_usa
# Out:
#         job_index       job_title_short  \
# 0               0  Senior Data Engineer
# 1               3         Data Engineer
# 2               5         Data Engineer
# 3               6  Senior Data Engineer
# 4               9        Data Scientist
# ...           ...                   ...
# 206287     785673        Data Scientist
# 206288     785685          Data Analyst
# 206289     785692        Data Scientist
# 206290     785703          Data Analyst
# 206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 4                                       Data Scientist II          Anywhere
# ...

# %%
df_usa=df[df['job_country']=='United States']
df_usa.reset_index(inplace=True)
df_usa

# %%
df_usa.set_index('job_index',inplace=True)
df_usa
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# ...                         ...
# 785673           Data Scientist
# 785685             Data Analyst
# 785692           Data Scientist
# 785703             Data Analyst
# 785705             Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# 785673                       Asset Management Data Scientist
# ...

# %%
median_pivot = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc=('median','min','max'))
median_pivot
# Out:
#                                 max    median      min
# job_title_short
# Business Analyst           387460.0   85000.0  16500.0
# Cloud Engineer             280000.0   90000.0  42000.0
# Data Analyst               650000.0   90000.0  25000.0
# Data Engineer              525000.0  125000.0  15000.0
# Data Scientist             960000.0  127500.0  27000.0
# Machine Learning Engineer  325000.0  106415.0  30000.0
# Senior Data Analyst        425000.0  111175.0  30000.0
# Senior Data Engineer       425000.0  147500.0  35000.0
# Senior Data Scientist      890000.0  155500.0  45000.0
# Software Engineer          375000.0   99150.0  28000.0

# %%
median_pivot.sort_values(by= ('median') ,ascending = False)
# Out:
#                              median      min
# job_title_short
# Senior Data Scientist      155500.0  45000.0
# Senior Data Engineer       147500.0  35000.0
# Data Scientist             127500.0  27000.0
# Data Engineer              125000.0  15000.0
# Senior Data Analyst        111175.0  30000.0
# Machine Learning Engineer  106415.0  30000.0
# Software Engineer           99150.0  28000.0
# Cloud Engineer              90000.0  42000.0
# Data Analyst                90000.0  25000.0
# Business Analyst            85000.0  16500.0

# %% [markdown]
# <span style = " color:green;font-width:bold; font-size:32px;"> Practise Prompts </span>

# %%
# Problem Statement:
# Set the job_posted_date column as the index of the DataFrame and display the first 5 rows.
df_index=df.copy()
df_index.set_index('job_posted_date',inplace=True)
df_index.head(5)
# Out:
#                           job_title_short  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Data Engineer
# 2023-01-14 13:18:07          Data Analyst
# 2023-10-10 13:14:55         Data Engineer
# 2023-07-04 13:01:41         Data Engineer
# 2023-08-07 14:29:36         Data Engineer
#
#                                                              job_title  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Clinical Data Engineer / Principal Clin...
# 2023-01-14 13:18:07                                       Data Analyst
# 2023-10-10 13:14:55  Data Engineer/Scientist/Analyst, Mid or Senior...
# 2023-07-04 13:01:41  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2023-08-07 14:29:36                             Data Engineer- Sr Jobs
#
#                                      job_location             job_via  \
# job_posted_date
# 2023-06-16 13:44:15                 Watertown, CT     via Work Nearby
# 2023-01-14 13:18:07  Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
# Problem Statement:
# Reset the index of the DataFrame from the last problem (where job_posted_date column is the index) to the default integer index 
# and drop the existing index. Display the first 5 rows.
df_index.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jn/vgbqf59j1693g125bwzg03m40000gn/T/ipykernel_71408/914995858.py in ?()
# ----> 4 # Problem Statement:
#       5 # Reset the index of the DataFrame from the last problem (where job_posted_date column is the index) to the default integer index
#       6 # and drop the existing index. Display the first 5 rows.
#       7 df_index.reset_index(inplace=True)
#
# ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
# ...

# %%
# Problem Statement:
# Create a pivot table to calculate the median salary_year_avg for each company_name and sort the index in descending order. 
# Display the first 5 rows.
pivot_table = df.pivot_table(values='salary_year_avg', index='company_name', aggfunc='median')
pivot_table.sort_index(inplace=True, ascending=False)
pivot_table.head()
# Out:
#                                     salary_year_avg
# company_name
# ​Illinois State Board of Education          62536.0
# Технологическая компания                   280000.0
# ЛАНИТ                                      400000.0
# ztp                                         95000.0
# zooplus SE                                 161750.0

# %%
# Problem Statement:
# Create a pivot table to calculate the median salary_year_avg for each job_title_short, reset the index of the resulting pivot table, 
# then set the index to salary_year_avg. 
# Display the first 5 rows.

pivot_table = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
pivot_table.reset_index(inplace=True)
pivot_table.set_index('salary_year_avg', inplace=True)
pivot_table
# Out:
#                            job_title_short
# salary_year_avg
# 85000.0                   Business Analyst
# 90000.0                     Cloud Engineer
# 90000.0                       Data Analyst
# 125000.0                     Data Engineer
# 127500.0                    Data Scientist
# 106415.0         Machine Learning Engineer
# 111175.0               Senior Data Analyst
# 147500.0              Senior Data Engineer
# 155500.0             Senior Data Scientist
# 99150.0                  Software Engineer

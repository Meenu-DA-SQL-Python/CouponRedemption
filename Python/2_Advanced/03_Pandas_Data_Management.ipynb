# %%
import pandas as pd
from datasets import load_dataset
import numpy as np
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.sample(5,random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
# ...

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()
df_copy=df_original

median_salary=df_original['salary_year_avg'].median()

median_salary
# Out:
# np.float64(115000.0)

# %%
df_original['salary_year_avg']=df_original['salary_year_avg'].fillna(median_salary)

df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_copy.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_copy)==id(df_original)
# Out:
# True

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                4990074016
# ID of df_altered:                 4990073872
# Are the two dataframes the same?  False

# %% [markdown]
# <span style ="color:green; font-width:bold ; font-size:32px ;" > Practise prompts </span>

# %%
# Problem Statement:
# Create a copy of the DataFrame and drop rows where the salary_year_avg column has missing values.
# Display the first 5 rows of the cleaned DataFrame.

import pandas as pd
from datasets import load_dataset
import numpy as np
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()
df_copy=df_original.copy()
print(len(df_original))

df_copy=df_copy.dropna(subset=['salary_year_avg'])

print(len(df_copy))
# Out:
# 785741
# 22003

# %%
# Problem Statement:
# Create a new DataFrame that is a random sample of 10% of the original DataFrame.
# Display the first 5 rows of the sampled DataFrame.
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df_sampled = df.sample(frac=0.1)
df_sampled.head(5)
# Out:
#              job_title_short  \
# 39234         Data Scientist
# 135756        Cloud Engineer
# 132925          Data Analyst
# 112219  Senior Data Engineer
# 518056         Data Engineer
#
#                                                job_title  \
# 39234                                          Scientist
# 135756     IT Infrastructure and Digitalization Engineer
# 132925           Data Analyst, Alternate Solutions Group
# 112219  Senior Data Engineer | 資深資料工程師 (引客數據 invos Data)
# 518056             Data Engineer (6200 USD/Mes) [Remote]
#
#                    job_location             job_via        job_schedule_type  \
# 39234   Wellington, New Zealand     via Trabajo.org  Full-time and Temp work
# 135756                 Malaysia  via BeBee Malaysia                Full-time
# 132925                   Canada    via BeBee Canada                Full-time
# 112219      Taipei City, Taiwan           via Melga                     None
# ...

# %%
# Problem Statement:
# Create a copy of the original DataFrame and fill in missing values in the salary_year_avg column with the median salary. 
# Display the first 5 rows of the altered DataFrame.

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df_copy = df.copy()
median_salary = df_copy['salary_year_avg'].median()
df_copy['salary_year_avg'] = df_copy['salary_year_avg'].fillna(median_salary)
df_copy.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

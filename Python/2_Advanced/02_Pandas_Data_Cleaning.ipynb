# %%
import pandas as pd
from datasets import load_dataset
import numpy as np
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])


df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
median_salary_year=df['salary_year_avg'].median()
median_salary_year
# Out:
# np.float64(115000.0)

# %%
median_hour_year = df['salary_hour_avg'].median()
median_hour_year
# Out:
# np.float64(45.97999954223633)

# %%
df_filled=df

df_filled['salary_hour_avg']=df_filled['salary_hour_avg'].fillna(median_hour_year)


df_filled.loc[1:100,['job_title','salary_hour_avg']]
# Out:
#                                              job_title  salary_hour_avg
# 1                                         Data Analyst            45.98
# 2    Data Engineer/Scientist/Analyst, Mid or Senior...            45.98
# 3    LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...            45.98
# 4                               Data Engineer- Sr Jobs            45.98
# 5                                    GCP Data Engineer            45.98
# ..                                                 ...              ...
# 96                                       Data Engineer            45.98
# 97   Systems & Data Analyst - Exploitation, Missing...            45.98
# 98                          Senior Data Engineer (AWS)            45.98
# 99   Senior/Staff Data Engineer – Apache Spark (Jav...            45.98
# 100            Data Scientist, Risk Data Mining - USDS            45.98
#
# [100 rows x 2 columns]

# %%
df_filled['salary_year_avg']=df_filled['salary_year_avg'].fillna(median_salary_year)


df_filled.loc[1:100,['job_title','salary_year_avg']]
# Out:
#                                              job_title  salary_year_avg
# 1                                         Data Analyst         115000.0
# 2    Data Engineer/Scientist/Analyst, Mid or Senior...         115000.0
# 3    LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...         115000.0
# 4                               Data Engineer- Sr Jobs         115000.0
# 5                                    GCP Data Engineer         115000.0
# ..                                                 ...              ...
# 96                                       Data Engineer         115000.0
# 97   Systems & Data Analyst - Exploitation, Missing...         115000.0
# 98                          Senior Data Engineer (AWS)         115000.0
# 99   Senior/Staff Data Engineer – Apache Spark (Jav...         115000.0
# 100            Data Scientist, Risk Data Mining - USDS         228222.0
#
# [100 rows x 2 columns]

# %%
df_unique=df_filled

len_dffilled=len(df_filled)

print(len_dffilled)


df_unique=df_unique.drop_duplicates()

len_unique=len(df_unique)

print(len_unique)

row_dropped=len_dffilled-len_unique

print(row_dropped)
# Out:
# 785741
# 785640
# 101

# %%
df_unique=df_unique.drop_duplicates( subset =['job_title','company_name'])

len_unique=len(df_unique)
print(

row_dropped=len_dffilled-len_unique

print(row_dropped)
# Out:
# 277699

# %% [markdown]
# # Practise Prompts

# %%
# Problem Statement:
# Remove rows where the salary_year_avg column has missing values. Display the number of rows before and after removing.
df_practise=df
df_practise

before_drop=len(df_practise)
print(before_drop)
# Out:
# 785741

# %%
df_practise= df_practise.dropna(subset=['salary_year_avg'])
after_drop=len(df_practise)
print(after_drop)

df_practise
# Out:
# 22003
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
# Problem Statement:
# Remove duplicate rows from the DataFrame based on the job_location column. 
# Display the number of rows before and after removing duplicates.

import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
rows_before = df.shape[0]
df_unique = df.drop_duplicates(subset=['job_location'])
rows_after = df_unique.shape[0]
rows_before, rows_after
# Out:
# (785741, 17218)

# %%
# Problem Statement:
# Fill missing values in the salary_rate column with the string 'Unknown'. 
# Display the first 10 rows of the salary_rate column before and after filling.

import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

salary_rate_before = df['salary_rate'].head(10)

df_filled = df.fillna({'salary_rate': 'Unknown'})

salary_rate_after = df_filled['salary_rate'].head(10)
salary_rate_before, salary_rate_after
# Out:
# (0    None
#  1    None
#  2    None
#  3    None
#  4    None
#  5    None
#  6    None
#  7    None
#  8    None
#  9    None
#  Name: salary_rate, dtype: object,
#  0    Unknown
#  1    Unknown
#  2    Unknown
#  3    Unknown
#  4    Unknown
#  5    Unknown
#  6    Unknown
#  7    Unknown
#  8    Unknown
#  9    Unknown
#  Name: salary_rate, dtype: object)

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Saving the DataFrame to a CSV file
df.to_csv('jobs_data.csv', index=False)

# %%
df_DA = df[(df['job_title_short'] == 'Data Analyst')].copy()
df_DA['job_posted_month'] = df_DA['job_posted_date'].dt.strftime('%b')

months = df_DA['job_posted_month'].unique()
df_DA_month = {}
for month in months:
    df_DA_month[month] = df_DA[df_DA['job_posted_month'] == month].copy()

quarter_1 = [df_DA_month['Jan'], df_DA_month['Feb'], df_DA_month['Mar']]
df_concat = pd.concat(quarter_1, ignore_index=True)

df_concat
# Out:
#       job_title_short                                          job_title  \
# 0        Data Analyst                                       Data Analyst
# 1        Data Analyst                               Data Analyst (m/f/d)
# 2        Data Analyst                                       Data Analyst
# 3        Data Analyst    Projects & Solutions Data Analyst (UK Pensions)
# 4        Data Analyst  Data Base work from home job/internship at Mga...
# ...               ...                                                ...
# 56381    Data Analyst                   Oracle Supply Chain Data Analyst
# 56382    Data Analyst                               Data Analyst (m/w/d)
# 56383    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 56384    Data Analyst                 Data & Analytics Architect (w/m/x)
# 56385    Data Analyst                                   CRM Data Analyst
#
#                                  job_location  \
# 0                Guadalajara, Jalisco, Mexico
# 1                          Nuremberg, Germany
# 2                                   Tampa, FL
# 3                              Birmingham, UK
# 4                                    Anywhere
# ...                                       ...
# 56381  Quezon City, Metro Manila, Philippines
# 56382                            Jena, Jerman
# 56383                                   India
# 56384                          Erfurt, Jerman
# 56385                      Bad Rodach, Jerman
#
#                                                  job_via job_schedule_type  \
# 0                                       via BeBee México         Full-time
# 1                                   via Big Country Jobs         Full-time
# 2                                           via LinkedIn         Full-time
# 3                                           via LinkedIn         Full-time
# 4                                           via LinkedIn         Full-time
# ...                                                  ...               ...
# 56381                                    via Trabajo.org         Full-time
# 56382                                       melalui XING   Pekerjaan tetap
# 56383  melalui Jobsleworld - Jobs In India - Job Vaca...   Pekerjaan tetap
# 56384                                   melalui LinkedIn   Pekerjaan tetap
# 56385                          melalui BeBee Deutschland   Pekerjaan tetap
#
#        job_work_from_home         search_location     job_posted_date  \
# 0                   False                  Mexico 2023-01-14 13:18:07
# 1                   False                 Germany 2023-01-19 14:05:05
# 2                   False  Florida, United States 2023-01-19 13:19:45
# 3                   False          United Kingdom 2023-01-04 13:35:45
# 4                    True                   India 2023-01-14 13:11:58
# ...                   ...                     ...                 ...
# 56381               False             Philippines 2023-03-11 06:29:07
# 56382               False                 Germany 2023-03-12 06:18:18
# 56383               False                   India 2023-03-13 06:16:28
# 56384               False                 Germany 2023-03-12 06:18:18
# 56385               False                 Germany 2023-03-12 06:18:18
#
#        job_no_degree_mention  job_health_insurance     job_country  \
# 0                      False                 False          Mexico
# 1                      False                 False         Germany
# 2                      False                 False   United States
# 3                      False                 False  United Kingdom
# 4                      False                 False           India
# ...                      ...                   ...             ...
# 56381                  False                 False     Philippines
# 56382                  False                 False         Germany
# 56383                  False                 False           India
# 56384                  False                 False         Germany
# 56385                  False                 False         Germany
#
#       salary_rate  salary_year_avg  salary_hour_avg  \
# 0            None              NaN              NaN
# 1            None              NaN              NaN
# 2            None              NaN              NaN
# 3            None              NaN              NaN
# 4            None              NaN              NaN
# ...           ...              ...              ...
# 56381        None              NaN              NaN
# 56382        None              NaN              NaN
# 56383        None              NaN              NaN
# 56384        None              NaN              NaN
# 56385        None              NaN              NaN
#
#                      company_name  \
# 0      Hewlett Packard Enterprise
# 1                         Symanto
# 2                            Citi
# 3                             Aon
# 4                       Mgadz Inc
# ...                           ...
# 56381                     emerson
# 56382              linimed Gruppe
# 56383                        Amul
# 56384               NTT DATA DACH
# 56385            HABA FAMILYGROUP
#
#                                               job_skills  \
# 0      ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1      ['python', 'r', 'sql', 'azure', 'power bi', 'e...
# 2             ['sql', 'python', 'unix', 'excel', 'jira']
# 3                                       ['sql', 'excel']
# 4                                  ['sas', 'sas', 'sql']
# ...                                                  ...
# 56381                                         ['oracle']
# 56382                ['sql', 'julia', 'power bi', 'dax']
# 56383                                               None
# 56384                                   ['aws', 'azure']
# 56385                     ['sas', 'sas', 'sql', 'excel']
#
#                                          job_type_skills job_posted_month
# 0      {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1      {'analyst_tools': ['power bi', 'excel', 'power...              Jan
# 2      {'analyst_tools': ['excel'], 'async': ['jira']...              Jan
# 3      {'analyst_tools': ['excel'], 'programming': ['...              Jan
# 4      {'analyst_tools': ['sas'], 'programming': ['sa...              Jan
# ...                                                  ...              ...
# 56381                              {'cloud': ['oracle']}              Mar
# 56382  {'analyst_tools': ['power bi', 'dax'], 'progra...              Mar
# 56383                                               None              Mar
# 56384                        {'cloud': ['aws', 'azure']}              Mar
# 56385  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
#
# [56386 rows x 18 columns]

# %%
# Saving the DataFrame to a CSV file
df_concat.to_csv('jobs_1st_quarter.csv', index=False)

# %%
# Export the DataFrame to a CSV file named data_jobs_export.csv without including the index. Inspect the contents of the CSV exported.

df.to_csv('data_jobs_export.csv', index=False)

# %%
# Problem Statement:
# Filter the DataFrame to include only job postings with 'Data Scientist' in the job_title_short column.
# Export the filtered DataFrame to a CSV file named data_scientist_jobs.csv without including the index.
# Inspect that the CSV has been exported with the correct filtered data.
df_filtered = df[df['job_title_short'] == 'Data Scientist']
df_filtered.to_csv('data_scientist_jobs.csv', index=False)

# %%
# Problem Statement:
# Filter the DataFrame to include only job postings with 'New York, NY' in the job_location column.
# Export the filtered DataFrame to an Excel file named new_york_jobs.xlsx without including the index.
# Display the first 5 rows of the filtered DataFrame to confirm the export.

df_filtered1 = df[df['job_location'] == 'New York, NY']
df_filtered1.to_excel('new_york_jobs.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 7
#       1 # Problem Statement:
#       2 # Filter the DataFrame to include only job postings with 'New York, NY' in the job_location column.
#       3 # Export the filtered DataFrame to an Excel file named new_york_jobs.xlsx without including the index.
#       4 # Display the first 5 rows of the filtered DataFrame to confirm the export.
#       6 df_filtered1 = df[df['job_location'] == 'New York, NY']
# ----> 7 df_filtered1.to_excel('new_york_jobs.xlsx', index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/formats/excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/excel/_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'
